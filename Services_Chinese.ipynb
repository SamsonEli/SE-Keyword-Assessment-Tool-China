# %%
#Services (Chinese)

Content=input("Enter string:").upper()
L1=['''指导''','''教导''','''教练''','''教育''' ,'''训练''' ,'''辅导''','''辅导人''','''自动化培训''','''电气技能培训''','''电气安装课程''','''电气安全培训''','''电气培训''','''电气培训中心''','''电气培训课程''','''工业自动化培训''','''PLC培训''','''提供服务''' ,'''服务''' ,'''检修'''  ,'''维修''','''自动化服务''','''自动化服务''','''关键设施''','''客户支持''','''数字化服务''','''配电''','''配电''','''成套柜部件''','''现场服务''','''工业自动化服务''','''生命周期服务''','''专家服务''','''支持''','''公告''','''忠告''','''报告''' ,'''警告''' ,'''估价''' ,'''测评''','''评价''','''评估''','''评定''','''自动化顾问''','''自动化咨询服务''','''咨询 ''','''电气数字孪生''','''配电审计''','''配电咨询''','''电能质量分析''','''单线图''','''网络安全服务''','''网络安全培训''','''数据中心安装服务''','''工业网络安全''','''增强现实 ''','''自动维护''','''基于条件''','''基于条件的分析''','''无接触维护''','''数据中心维护服务''','''数据中心设施''','''服务派单''','''维护自动化''','''维护指标''','''维护计划'''  ,'''规范性维护''','''预防性维护配电系统''','''服务合同''','''服务计划''','''UPS机群管理''','''虚拟现实 ''','''资产连接''','''数据中心升级改造''','''基础设施升级改造''','''PLC迁移''','''回收''','''翻新''','''更新''','''改造''','''收回''','''弧闪''','''弧闪保护''','''弧闪保护系统''','''资产生命周期''','''自动化安全服务''','''电弧保护''','''电闪''','''电气安全''','''电气安全服务''','''电气安全培训''','''闪电''','''闪光设备''','''闪光保护''','''工业网络安全''','''安全服务公司''','''电气备件''','''电气备件''','''电气备件清单''','''备件''','''开关柜备件''','''UPS电池更换''','''UPS电池更换''','''UPS电池服务''','''UPS故障''','''UPS机群''']
mention_count1=0
keyword_count1=0
for x  in L1:
    y=Content.count(x)
    if y!=0:
     print(x,y)
     mention_count1 = mention_count1+y
     keyword_count1=keyword_count1+1
print("----Total Count----")
print("Keyword Count :",keyword_count1,"   Mention Count :",mention_count1)
# Out:
# Enter string:教練
# ----Total Count----
# Keyword Count : 0    Mention Count : 0
